# %%
import unittest
from test_character import TestCharacter
from test_alien import TestAlien
from test_player import TestPlayer
from test_sparkLance import TestSparkLance

def my_suite():
    
    suite = unittest.TestSuite()
    result = unittest.TestResult()
    
    suite.addTest(unittest.makeSuite(TestCharacter))
    suite.addTest(unittest.makeSuite(TestAlien))
    suite.addTest(unittest.makeSuite(TestPlayer))
    suite.addTest(unittest.makeSuite(TestSparkLance))
    
    runner = unittest.TextTestRunner()
    print(runner.run(suite))

my_suite()
# Out:
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
# test_display (test_character.TestCharacter) ... ok
# test_fight (test_character.TestCharacter) ... ok
# test_wound (test_character.TestCharacter) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.003s
#
# OK
# test_die (test_alien.TestAlien) ... ok
# test_dropMoney (test_alien.TestAlien) ... ok
# test_getName (test_alien.TestAlien) ... ok
# test_isdead (test_alien.TestAlien) ... ok
# test_wound (test_alien.TestAlien) ... ok
# test_display (test_character.TestCharacter) ... ok
# test_fight (test_character.TestCharacter) ... ok
# test_wound (test_character.TestCharacter) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.006s
#
# OK
# test_die (test_alien.TestAlien) ... ok
# test_dropMoney (test_alien.TestAlien) ... ok
# test_getName (test_alien.TestAlien) ... ok
# test_isdead (test_alien.TestAlien) ... ok
# test_wound (test_alien.TestAlien) ... ok
# test_display (test_character.TestCharacter) ... ok
# test_fight (test_character.TestCharacter) ... ok
# test_wound (test_character.TestCharacter) ... ok
# test_advance (test_player.TestPlayer) ... ok
# test_getMoney (test_player.TestPlayer) ... ok
# test_getidentity (test_player.TestPlayer) ... ok
# test_pay (test_player.TestPlayer) ... ok
# test_retreat (test_player.TestPlayer) ... ok
# test_showMoney (test_player.TestPlayer) ... ok
# test_wound (test_player.TestPlayer) ... ok
#
# ----------------------------------------------------------------------
# Ran 15 tests in 0.013s
#
# OK
# .................
# ----------------------------------------------------------------------
# Ran 17 tests in 0.006s
#
# OK
#                        վ'ᴗ' ի you advanced
#
#                        վ'ᴗ' ի you advanced
#
#                        վ'ᴗ' ի you advanced
#
#                        վ'ᴗ' ի you advanced
#
#                        (;´・`)> Can't advance further
#
#
#                                     You reclaimed $5 from the dead alien, they must have stolen these cash
#                                     from someone's backpack
#
#                                     You reclaimed $abc from the dead alien, they must have stolen these cash
#                                     from someone's backpack
# You found something strange from the alien
#
#
#
#
#                        (;´・`)> There is no other place to go
#
#                        վ'ᴗ' ի you advanced
#
#                       ヽ(*。>Д<)o゜ you retreated
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                        վ'ᴗ' ի you advanced
#
#                        վ'ᴗ' ի you advanced
#
#                        վ'ᴗ' ի you advanced
#
#                        վ'ᴗ' ի you advanced
#
#                        (;´・`)> Can't advance further
#
#
#                                     You reclaimed $5 from the dead alien, they must have stolen these cash
#                                     from someone's backpack
#
#                                     You reclaimed $abc from the dead alien, they must have stolen these cash
#                                     from someone's backpack
# You found something strange from the alien
#
#
#
#
#                        (;´・`)> There is no other place to go
#
#                        վ'ᴗ' ի you advanced
#
#                       ヽ(*。>Д<)o゜ you retreated
#
#
#
#
#
#
#
#
# <unittest.runner.TextTestResult run=17 errors=0 failures=0>
